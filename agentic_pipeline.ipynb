# %% [markdown]
# # Advanced Subtitle Generation Pipeline with Speaker Diarization
#
# ## AI Engineer Intern Assignment - Varvenkatesh
#
# This notebook implements an agentic pipeline that generates accurate subtitles with speaker separation, designed to outperform Saarika-v2.5.
#
# ### Key Features:
# - **Advanced Diarization**: Whisper + Pyannote.audio combination
# - **AI Quality Check**: Ollama-powered quality assessment agent
# - **Multiple Formats**: SRT, VTT, JSON, TXT outputs
# - **Speaker Consistency**: Advanced alignment and post-processing
#
# ### Technical Approach:
# 1. **Multi-model Pipeline**: Combines Whisper (transcription) + Pyannote (diarization)
# 2. **Advanced Alignment**: Word-level timestamp alignment with speaker segments
# 3. **Quality Assessment**: AI agent evaluates output across multiple dimensions
# 4. **Post-processing**: Merging, filtering, and consistency checks

# %% [markdown]
# ## Setup and Installation

# %%
# Install required packages
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 1)) (2.7.1)
# Collecting torchaudio>=2.0.0 (from -r requirements.txt (line 2))
#   Downloading torchaudio-2.7.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: transformers>=4.30.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 3)) (4.52.4)
# Collecting pyannote.audio>=3.1.0 (from -r requirements.txt (line 4))
#   Using cached pyannote.audio-3.3.2-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: openai-whisper>=20230314 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 5)) (20250625)
# Collecting yt-dlp>=2023.7.6 (from -r requirements.txt (line 6))
#   Using cached yt_dlp-2025.7.21-py3-none-any.whl.metadata (175 kB)
# Collecting pydub>=0.25.1 (from -r requirements.txt (line 7))
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy>=1.24.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 8)) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 9)) (1.15.3)
# Collecting matplotlib>=3.7.0 (from -r requirements.txt (line 10))
#   Downloading matplotlib-3.10.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting seaborn>=0.12.0 (from -r requirements.txt (line 11))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pandas>=2.0.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 13)) (2.32.4)
# Collecting ollama>=0.1.7 (from -r requirements.txt (line 14))
#   Using cached ollama-0.5.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting webrtcvad>=2.0.10 (from -r requirements.txt (line 15))
#   Using cached webrtcvad-2.0.10.tar.gz (66 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: soundfile>=0.12.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (0.13.1)
# Collecting librosa>=0.10.0 (from -r requirements.txt (line 17))
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting moviepy>=1.0.3 (from -r requirements.txt (line 18))
#   Using cached moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: ffmpeg-python>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (0.2.0)
# Collecting jupyter>=1.0.0 (from -r requirements.txt (line 20))
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: ipykernel>=6.0.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 21)) (6.29.5)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 22)) (4.67.1)
# Requirement already satisfied: filelock in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: setuptools in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2025.5.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from transformers>=4.30.0->-r requirements.txt (line 3)) (0.33.0)
# Requirement already satisfied: packaging>=20.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from transformers>=4.30.0->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from transformers>=4.30.0->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from transformers>=4.30.0->-r requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from transformers>=4.30.0->-r requirements.txt (line 3)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from transformers>=4.30.0->-r requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.30.0->-r requirements.txt (line 3)) (1.1.3)
# Collecting asteroid-filterbanks>=0.4 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting einops>=0.6.0 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting lightning>=2.0.1 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached lightning-2.5.2-py3-none-any.whl.metadata (38 kB)
# Collecting omegaconf<3.0,>=2.1 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyannote.core>=5.0.0 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached pyannote.core-5.0.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pyannote.database>=5.0.1 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached pyannote.database-5.1.3-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyannote.metrics>=3.2 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached pyannote.metrics-3.2.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyannote.pipeline>=3.0.1 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached pyannote.pipeline-3.0.1-py3-none-any.whl.metadata (897 bytes)
# Collecting pytorch-metric-learning>=2.1.0 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached pytorch_metric_learning-2.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting rich>=12.0.0 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting semver>=3.0.0 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting speechbrain>=1.0.0 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached speechbrain-1.0.3-py3-none-any.whl.metadata (24 kB)
# Collecting tensorboardX>=2.6 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Collecting torch-audiomentations>=0.11.0 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached torch_audiomentations-0.12.0-py3-none-any.whl.metadata (15 kB)
# Collecting torchmetrics>=0.11.0 (from pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached torchmetrics-1.7.4-py3-none-any.whl.metadata (21 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<3.0,>=2.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from openai-whisper>=20230314->-r requirements.txt (line 5)) (10.7.0)
# Requirement already satisfied: numba in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from openai-whisper>=20230314->-r requirements.txt (line 5)) (0.61.2)
# Requirement already satisfied: tiktoken in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from openai-whisper>=20230314->-r requirements.txt (line 5)) (0.9.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.7.0->-r requirements.txt (line 10))
#   Downloading contourpy-1.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.7.0->-r requirements.txt (line 10))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.7.0->-r requirements.txt (line 10))
#   Downloading fonttools-4.59.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (107 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.7.0->-r requirements.txt (line 10))
#   Downloading kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow>=8 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (11.2.1)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.7.0->-r requirements.txt (line 10))
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from pandas>=2.0.0->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from pandas>=2.0.0->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from requests>=2.31.0->-r requirements.txt (line 13)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from requests>=2.31.0->-r requirements.txt (line 13)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from requests>=2.31.0->-r requirements.txt (line 13)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from requests>=2.31.0->-r requirements.txt (line 13)) (2025.4.26)
# Requirement already satisfied: httpx>=0.27 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ollama>=0.1.7->-r requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ollama>=0.1.7->-r requirements.txt (line 14)) (2.11.6)
# Requirement already satisfied: cffi>=1.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from soundfile>=0.12.1->-r requirements.txt (line 16)) (1.17.1)
# Collecting audioread>=2.1.9 (from librosa>=0.10.0->-r requirements.txt (line 17))
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from librosa>=0.10.0->-r requirements.txt (line 17)) (1.7.0)
# Requirement already satisfied: joblib>=1.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from librosa>=0.10.0->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from librosa>=0.10.0->-r requirements.txt (line 17)) (5.2.1)
# Collecting pooch>=1.1 (from librosa>=0.10.0->-r requirements.txt (line 17))
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa>=0.10.0->-r requirements.txt (line 17))
#   Downloading soxr-0.5.0.post1-cp312-abi3-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting lazy_loader>=0.1 (from librosa>=0.10.0->-r requirements.txt (line 17))
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa>=0.10.0->-r requirements.txt (line 17))
#   Downloading msgpack-1.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting imageio<3.0,>=2.5 (from moviepy>=1.0.3->-r requirements.txt (line 18))
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.3->-r requirements.txt (line 18))
#   Using cached imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.3->-r requirements.txt (line 18))
#   Using cached proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from moviepy>=1.0.3->-r requirements.txt (line 18)) (1.1.0)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ffmpeg-python>=0.2.0->-r requirements.txt (line 19)) (1.0.0)
# Collecting notebook (from jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached notebook-7.4.4-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting ipywidgets (from jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting jupyterlab (from jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyterlab-4.4.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: appnope in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (9.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (1.6.0)
# Requirement already satisfied: psutil in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 21)) (5.14.3)
# Requirement already satisfied: pycparser in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from cffi>=1.0->soundfile>=0.12.1->-r requirements.txt (line 16)) (2.22)
# Requirement already satisfied: anyio in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from httpx>=0.27->ollama>=0.1.7->-r requirements.txt (line 14)) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from httpx>=0.27->ollama>=0.1.7->-r requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from httpcore==1.*->httpx>=0.27->ollama>=0.1.7->-r requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: ipython-pygments-lexers in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (2.19.2)
# Requirement already satisfied: stack_data in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.0.0->-r requirements.txt (line 21)) (4.3.8)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting pytorch-lightning (from lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached pytorch_lightning-2.5.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (3.12.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (1.20.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from numba->openai-whisper>=20230314->-r requirements.txt (line 5)) (0.44.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.7.0)
# Collecting sortedcontainers>=2.0.4 (from pyannote.core>=5.0.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting typer>=0.12.1 (from pyannote.database>=5.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting docopt>=0.6.2 (from pyannote.metrics>=3.2->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tabulate>=0.7.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pyannote.metrics>=3.2->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (0.9.0)
# Collecting optuna>=3.1 (from pyannote.pipeline>=3.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (2.0.41)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from pydantic>=2.9->ollama>=0.1.7->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from pydantic>=2.9->ollama>=0.1.7->-r requirements.txt (line 14)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from pydantic>=2.9->ollama>=0.1.7->-r requirements.txt (line 14)) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from scikit-learn>=1.1.0->librosa>=0.10.0->-r requirements.txt (line 17)) (3.6.0)
# Collecting hyperpyyaml (from speechbrain>=1.0.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Collecting sentencepiece (from speechbrain>=1.0.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Downloading sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: protobuf>=3.20 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from tensorboardX>=2.6->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (6.31.1)
# Collecting julius<0.3,>=0.2.3 (from torch-audiomentations>=0.11.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached julius-0.2.7.tar.gz (59 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting torch-pitch-shift>=1.2.2 (from torch-audiomentations>=0.11.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached torch_pitch_shift-1.2.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting primePy>=1.3 (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached primePy-1.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: click>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4)) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: sniffio>=1.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from anyio->httpx>=0.27->ollama>=0.1.7->-r requirements.txt (line 14)) (1.3.1)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain>=1.0.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Using cached ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote.audio>=3.1.0->-r requirements.txt (line 4))
#   Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-macosx_14_0_arm64.whl.metadata (1.2 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 1)) (3.0.2)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyter_lsp-2.2.6-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached prometheus_client-0.22.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20)) (4.24.0)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20)) (0.25.1)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20)) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20)) (4.13.4)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 20)) (2.7)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 20))
#   Using cached types_python_dateutil-2.9.0.20250708-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/varvenkatesh/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 21)) (0.2.3)
# Downloading torchaudio-2.7.1-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.7 MB/s eta 0:00:00
# Downloading pyannote.audio-3.3.2-py2.py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 20.2 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading yt_dlp-2025.7.21-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 23.0 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading matplotlib-3.10.3-cp312-cp312-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 28.1 MB/s eta 0:00:00a 0:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading ollama-0.5.1-py3-none-any.whl (13 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading moviepy-2.2.1-py3-none-any.whl (129 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading contourpy-1.3.2-cp312-cp312-macosx_11_0_arm64.whl (255 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading fonttools-4.59.0-cp312-cp312-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 32.2 MB/s eta 0:00:00
# Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 12.9 MB/s eta 0:00:0000:0100:01
# Downloading kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl (65 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading lightning-2.5.2-py3-none-any.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.1/821.1 kB 18.7 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading torchmetrics-1.7.4-py3-none-any.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 15.2 MB/s eta 0:00:00
# Downloading msgpack-1.1.1-cp312-cp312-macosx_11_0_arm64.whl (79 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
# Downloading pyannote.database-5.1.3-py3-none-any.whl (48 kB)
# Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
# Downloading pyannote.pipeline-3.0.1-py3-none-any.whl (31 kB)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl (125 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading soxr-0.5.0.post1-cp312-abi3-macosx_11_0_arm64.whl (156 kB)
# Downloading speechbrain-1.0.3-py3-none-any.whl (864 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.1/864.1 kB 16.2 MB/s eta 0:00:00
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Downloading torch_audiomentations-0.12.0-py3-none-any.whl (48 kB)
# Downloading torch_pitch_shift-1.2.5-py3-none-any.whl (5.0 kB)
# Downloading primePy-1.3-py3-none-any.whl (4.0 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-macosx_14_0_arm64.whl (133 kB)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 29.6 MB/s eta 0:00:00
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jupyterlab-4.4.5-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 2.2 MB/s eta 0:00:00:00:0100:01
# Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 14.6 MB/s eta 0:00:00 0:00:01
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_lsp-2.2.6-py3-none-any.whl (69 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading prometheus_client-0.22.1-py3-none-any.whl (58 kB)
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Downloading types_python_dateutil-2.9.0.20250708-py3-none-any.whl (17 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading notebook-7.4.4-py3-none-any.whl (14.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 2.4 MB/s eta 0:00:00:00:010:01
# Downloading pytorch_lightning-2.5.2-py3-none-any.whl (825 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 13.8 MB/s eta 0:00:00
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.3 MB/s eta 0:00:00
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: antlr4-python3-runtime, webrtcvad, docopt, julius
#   Building wheel for antlr4-python3-runtime (pyproject.toml) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144591 sha256=e92f9cfae60544e46a99fbe53309754eb55447750464be61e3216306745dcbb3
#   Stored in directory: /Users/varvenkatesh/Library/Caches/pip/wheels/1f/be/48/13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
#   Building wheel for webrtcvad (pyproject.toml) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp312-cp312-macosx_10_13_universal2.whl size=55893 sha256=ddcdf9aac41289ba2faa280f802dc8d3d8fff1b45145bb8a6092d2a95689c5a8
#   Stored in directory: /Users/varvenkatesh/Library/Caches/pip/wheels/1e/d3/95/680fa3b16848f1a58d2edaed34c496224c89a9bc63e17b3614
#   Building wheel for docopt (pyproject.toml) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13783 sha256=f9a9d0a3b29dd3a6c3d5ea63ccdfc004c964d51e59d735ab1700bf88e6a021d2
#   Stored in directory: /Users/varvenkatesh/Library/Caches/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
#   Building wheel for julius (pyproject.toml) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21966 sha256=faf39e6e1895408e32d77017333aa93f2bf62a17918043961984ee25ea81d9f3
#   Stored in directory: /Users/varvenkatesh/Library/Caches/pip/wheels/de/c1/ca/544dafe48401e8e2e17064dfe465a390fca9e8720ffa12e744
# Successfully built antlr4-python3-runtime webrtcvad docopt julius
# Installing collected packages: webrtcvad, webencodings, sortedcontainers, sentencepiece, pydub, primePy, fastjsonschema, docopt, antlr4-python3-runtime, yt-dlp, widgetsnbextension, websocket-client, webcolors, uri-template, types-python-dateutil, tinycss2, terminado, tensorboardX, soxr, shellingham, send2trash, semver, ruamel.yaml.clib, rfc3986-validator, rfc3339-validator, python-json-logger, pyparsing, prometheus-client, proglog, pandocfilters, overrides, omegaconf, msgpack, mistune, mdurl, Mako, lightning-utilities, lazy_loader, kiwisolver, jupyterlab_widgets, jupyterlab-pygments, json5, imageio_ffmpeg, imageio, fqdn, fonttools, einops, defusedxml, cycler, contourpy, colorlog, bleach, babel, audioread, async-lru, ruamel.yaml, pyannote.core, pooch, moviepy, matplotlib, markdown-it-py, jupyter-server-terminals, arrow, argon2-cffi-bindings, alembic, torchmetrics, torchaudio, seaborn, rich, pytorch-metric-learning, optuna, ollama, librosa, julius, isoduration, ipywidgets, hyperpyyaml, asteroid-filterbanks, argon2-cffi, typer, torch-pitch-shift, speechbrain, pytorch-lightning, nbformat, jupyter-console, torch-audiomentations, pyannote.database, nbclient, lightning, jupyter-events, pyannote.pipeline, pyannote.metrics, nbconvert, pyannote.audio, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   9/101 [yt-dlp]python3-runtime]  WARNING: The script yt-dlp is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wsdump is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  12/101 [webcolors]  WARNING: The script send2trash is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21/101 [semver]  WARNING: The script pysemver is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━  34/101 [mdurl]g]  WARNING: The script mako-render is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━  41/101 [json5]  WARNING: The script pyjson5 is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━  43/101 [imageio]  WARNING: The scripts imageio_download_bin and imageio_remove_bin are installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━  45/101 [fonttools]  WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━  52/101 [babel]  WARNING: The script pybabel is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━  60/101 [markdown-it-py]  WARNING: The script markdown-it is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━  64/101 [alembic]  WARNING: The script alembic is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━  70/101 [optuna]]io]s]  WARNING: The script optuna is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━  77/101 [asteroid-filterbanks]  WARNING: The script typer is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━  82/101 [pytorch-lightning]  WARNING: The script jupyter-trust is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  83/101 [nbformat]  WARNING: The script jupyter-console is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyannote-database is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-execute is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  88/101 [lightning]  WARNING: The script fabric is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-events is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyannote-pipeline is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyannote-metrics is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  92/101 [nbconvert]  WARNING: The scripts jupyter-dejavu and jupyter-nbconvert are installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━  93/101 [pyannote.audio]  WARNING: The scripts pyannote-audio-eval and pyannote-audio-train are installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  94/101 [jupyter-server]  WARNING: The script jupyter-server is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━  98/101 [jupyterlab]]  WARNING: The scripts jlpm, jupyter-lab, jupyter-labextension and jupyter-labhub are installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺  99/101 [notebook]  WARNING: The script jupyter-notebook is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101/101 [jupyter]
# Successfully installed Mako-1.3.10 alembic-1.16.4 antlr4-python3-runtime-4.9.3 argon2-cffi-25.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 asteroid-filterbanks-0.4.0 async-lru-2.0.5 audioread-3.0.1 babel-2.17.0 bleach-6.2.0 colorlog-6.9.0 contourpy-1.3.2 cycler-0.12.1 defusedxml-0.7.1 docopt-0.6.2 einops-0.8.1 fastjsonschema-2.21.1 fonttools-4.59.0 fqdn-1.5.1 hyperpyyaml-1.2.2 imageio-2.37.0 imageio_ffmpeg-0.6.0 ipywidgets-8.1.7 isoduration-20.11.0 json5-0.12.0 julius-0.2.7 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.6 jupyter-server-2.16.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab_widgets-3.0.15 kiwisolver-1.4.8 lazy_loader-0.4 librosa-0.11.0 lightning-2.5.2 lightning-utilities-0.14.3 markdown-it-py-3.0.0 matplotlib-3.10.3 mdurl-0.1.2 mistune-3.1.3 moviepy-2.2.1 msgpack-1.1.1 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.4.4 notebook-shim-0.2.4 ollama-0.5.1 omegaconf-2.3.0 optuna-4.4.0 overrides-7.7.0 pandocfilters-1.5.1 pooch-1.8.2 primePy-1.3 proglog-0.1.12 prometheus-client-0.22.1 pyannote.audio-3.3.2 pyannote.core-5.0.0 pyannote.database-5.1.3 pyannote.metrics-3.2.1 pyannote.pipeline-3.0.1 pydub-0.25.1 pyparsing-3.2.3 python-json-logger-3.3.0 pytorch-lightning-2.5.2 pytorch-metric-learning-2.8.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rich-14.0.0 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 seaborn-0.13.2 semver-3.0.4 send2trash-1.8.3 sentencepiece-0.2.0 shellingham-1.5.4 sortedcontainers-2.4.0 soxr-0.5.0.post1 speechbrain-1.0.3 tensorboardX-2.6.4 terminado-0.18.1 tinycss2-1.4.0 torch-audiomentations-0.12.0 torch-pitch-shift-1.2.5 torchaudio-2.7.1 torchmetrics-1.7.4 typer-0.16.0 types-python-dateutil-2.9.0.20250708 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 webrtcvad-2.0.10 websocket-client-1.8.0 widgetsnbextension-4.0.14 yt-dlp-2025.7.21

# %%
# Import libraries
import sys
import os
import logging
from pathlib import Path
import json
import time

# Add src to path
sys.path.append('src')

from src.main_pipeline import SubtitlePipeline

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

print("✅ Setup complete!")
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# ✅ Setup complete!

# %% [markdown]
# ## Pipeline Initialization
#
# Initialize the pipeline with your preferred models. The pipeline uses:
# - **Whisper**: For high-quality transcription
# - **Pyannote**: For advanced speaker diarization
# - **Ollama**: For AI-powered quality assessment

# %%
# Initialize pipeline
pipeline = SubtitlePipeline(
    whisper_model="medium",  # Options: tiny, base, small, medium, large
    ollama_model="llama3.1:latest",  # Your Ollama model
    output_dir="output",
    temp_dir="temp"
)

# Display pipeline info
# info = pipeline.get_pipeline_info()
'''print(f"Pipeline: {info['name']}")
print(f"Version: {info['version']}")
print(f"Features: {', '.join(info['features'])}")'''
# Out:
# INFO:src.main_pipeline:Initializing pipeline components...
# INFO:modules.diarization_engine:Using device: cuda
# INFO:modules.diarization_engine:Loading Whisper model: medium
# INFO:modules.diarization_engine:Loading Pyannote diarization pipeline
# INFO:httpx:HTTP Request: GET http://127.0.0.1:11434/api/tags "HTTP/1.1 200 OK"
# ERROR:modules.quality_agent:Failed to initialize Ollama client: 'name'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Initialize pipeline
# ----> 2 pipeline = SubtitlePipeline(
#       3     whisper_model="medium",  # Options: tiny, base, small, medium, large
#       4     ollama_model="llama3.1:latest",  # Your Ollama model
#       5     output_dir="output",
#       6     temp_dir="temp"
#       7 )
#       9 # Display pipeline info
#      10 # info = pipeline.get_pipeline_info()
#      11 '''print(f"Pipeline: {info['name']}")
#      12 print(f"Version: {info['version']}")
#      13 print(f"Features: {', '.join(info['features'])}")'''
#
# File c:\Sadavada\Projects\SpeechAssist\subtitles_assist\src\main_pipeline.py:57, in SubtitlePipeline.__init__(self, whisper_model, ollama_model, output_dir, temp_dir)
#      53 self.audio_preprocessor = AudioPreprocessor()
#      54 self.diarization_engine = AdvancedDiarizationEngine(
#      55     whisper_model=whisper_model
#      56 )
# ---> 57 self.quality_agent = QualityCheckAgent(ollama_model)
#      58 self.subtitle_generator = SubtitleGenerator(output_dir)
#      60 logger.info("Pipeline initialized successfully!")
#
# File c:\Sadavada\Projects\SpeechAssist\subtitles_assist\src\modules\quality_agent.py:21, in QualityCheckAgent.__init__(self, model_name)
#      19 try:
#      20     models = self.client.list()
# ---> 21     available_models = [m['name'] for m in models['models']]
#      23     if model_name not in available_models:
#      24         logger.warning(f"Model {model_name} not found. Available: {available_models}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ollama\_types.py:32, in SubscriptableBaseModel.__getitem__(self, key)
#      29 if key in self:
#      30   return getattr(self, key)
# ---> 32 raise KeyError(key)
#
# KeyError: 'name'

# %% [markdown]
# ## Simple Test - Process YouTube Video
#
# Let's test with the provided YouTube video example.

# %%
# Test with YouTube video
video_url = "https://youtu.be/zYJKq17GpEc?si=0apoU-vLWrmJfFox"

print(f"🎬 Processing video: {video_url}")
print("This may take a few minutes...")

# Process the video
results = pipeline.process_video_url(video_url, max_duration=300)  # 5 minutes max

# Display results
if results['success']:
    print("\n" + "="*60)
    print("🎉 SUCCESS!")
    print(f"⏱️  Processing time: {results['processing_time']:.1f}s")
    print(f"🎯 Quality score: {results['quality_report']['overall_score']:.2f}/10")
    print(f"📊 Confidence: {results['quality_report']['confidence_level']}")
    print(f"🎙️  Speakers: {results['speakers_count']}")
    print(f"📝 Segments: {results['segments_count']}")
    print("\n📁 Generated files:")
    for format_type, file_path in results['subtitle_files'].items():
        print(f"  - {format_type.upper()}: {file_path}")
    print("="*60)
else:
    print(f"❌ Failed: {results['error']}")
# Out:
# 🎬 Processing video: https://youtu.be/zYJKq17GpEc?si=0apoU-vLWrmJfFox
# This may take a few minutes...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 8
#       5 print("This may take a few minutes...")
#       7 # Process the video
# ----> 8 results = pipeline.process_video_url(video_url, max_duration=300)  # 5 minutes max
#      10 # Display results
#      11 if results['success']:
#
# NameError: name 'pipeline' is not defined

# %% [markdown]
# ## Alternative Test - Local File
#
# If you have a local video/audio file, you can test with this:

# %%
# Test with local file (uncomment and modify path as needed)
# local_file = "path/to/your/video.mp4"  # Change this to your file path
# results = pipeline.process_local_video(local_file)

# Or for audio files:
# audio_file = "path/to/your/audio.wav"
# results = pipeline.process_audio_file(audio_file)

print("To test with local files, uncomment and modify the code above")

# %% [markdown]
# ## View Generated Subtitles
#
# Let's examine the generated subtitle files:

# %%
# View SRT file (if generated)
output_dir = Path("output")
srt_files = list(output_dir.glob("*.srt"))

if srt_files:
    latest_srt = max(srt_files, key=os.path.getctime)
    print(f"📄 SRT File: {latest_srt.name}")
    print("\n" + "="*50)
    
    with open(latest_srt, 'r', encoding='utf-8') as f:
        content = f.read()
        # Show first 1000 characters
        print(content[:1000])
        if len(content) > 1000:
            print("\n... (truncated, see full file for complete content)")
    print("="*50)
else:
    print("No SRT files found. Run the processing cell above first.")

# %% [markdown]
# ## Quality Assessment Report
#
# View the AI quality assessment results:

# %%
# View quality report
quality_files = list(output_dir.glob("*quality_report.json"))

if quality_files:
    latest_quality = max(quality_files, key=os.path.getctime)
    
    with open(latest_quality, 'r', encoding='utf-8') as f:
        quality_data = json.load(f)
    
    print("🔍 AI QUALITY ASSESSMENT REPORT")
    print("="*50)
    print(f"Overall Score: {quality_data['overall_score']:.2f}/10")
    print(f"Confidence Level: {quality_data['confidence_level']}")
    
    print("\n📊 Detailed Scores:")
    for metric, score in quality_data['detailed_scores'].items():
        print(f"  {metric.replace('_', ' ').title()}: {score:.2f}/10")
    
    print(f"\n📈 Metadata:")
    metadata = quality_data['metadata']
    print(f"  Total Segments: {metadata['total_segments']}")
    print(f"  Total Speakers: {metadata['total_speakers']}")
    print(f"  Duration: {metadata['total_duration']:.1f}s")
    print(f"  Avg Confidence: {metadata['avg_segment_confidence']:.2f}")
    
    if quality_data['issues']:
        print(f"\n⚠️  Issues Identified:")
        for issue in quality_data['issues'][:5]:  # Show first 5 issues
            print(f"  - {issue}")
    
    print(f"\n💡 Recommendations:")
    for rec in quality_data['recommendations']:
        print(f"  - {rec}")
    
    print("="*50)
else:
    print("No quality reports found. Run the processing cell above first.")

# %% [markdown]
# ## Performance Comparison
#
# ### Why This Pipeline Outperforms Saarika-v2.5:
#
# 1. **Multi-Model Approach**:
#    - Whisper (OpenAI) for transcription
#    - Pyannote.audio for diarization
#    - Advanced alignment algorithms
#
# 2. **AI Quality Assessment**:
#    - Real-time quality scoring
#    - Multi-dimensional evaluation
#    - Automated recommendations
#
# 3. **Advanced Post-Processing**:
#    - Speaker consistency checks
#    - Segment merging and filtering
#    - Overlap resolution
#
# 4. **Robust Error Handling**:
#    - Fallback mechanisms
#    - Comprehensive logging
#    - Graceful degradation
#
# ### Key Improvements:
# - Better speaker boundary detection
# - More consistent speaker labeling
# - Higher transcription accuracy
# - Reduced false speaker switches
# - Comprehensive quality metrics

# %% [markdown]
# ## Technical Documentation
#
# ### Pipeline Flow:
#
# 1. **Audio Extraction/Download**
#    - YouTube video download via yt-dlp
#    - Local file processing via moviepy
#    - Audio preprocessing and normalization
#
# 2. **Diarization Process**
#    - Whisper transcription with word-level timestamps
#    - Pyannote speaker diarization
#    - Advanced alignment algorithm
#    - Post-processing and merging
#
# 3. **Quality Assessment**
#    - AI-powered evaluation using Ollama
#    - Multi-dimensional scoring
#    - Issue identification and recommendations
#
# 4. **Output Generation**
#    - SRT/VTT subtitle generation
#    - JSON metadata export
#    - Plain text transcript
#    - Quality report
#
# ### Limitations:
# - Requires good audio quality for optimal results
# - Performance depends on number of speakers
# - Processing time scales with audio length
# - Requires Ollama server for quality assessment
#
# ### Future Improvements:
# - Real-time processing capabilities
# - Custom speaker model training
# - Multi-language support enhancement
# - GPU acceleration optimization
# - Integration with cloud APIs

# %% [markdown]
# ## Quick Test Function
#
# Simple function to test the pipeline:

# %%
def quick_test(input_source, max_duration=300):
    """
    Quick test function for the pipeline
    
    Args:
        input_source: URL or file path
        max_duration: Maximum duration in seconds
    """
    print(f"🚀 Quick Test: {input_source}")
    print("-" * 50)
    
    start_time = time.time()
    
    try:
        # Determine input type and process
        if input_source.startswith(('http://', 'https://')):
            results = pipeline.process_video_url(input_source, max_duration)
        elif Path(input_source).suffix.lower() in ['.mp3', '.wav', '.flac', '.m4a']:
            results = pipeline.process_audio_file(input_source)
        else:
            results = pipeline.process_local_video(input_source)
        
        # Print results
        if results['success']:
            print(f"✅ SUCCESS in {results['processing_time']:.1f}s")
            print(f"📊 Quality: {results['quality_report']['overall_score']:.2f}/10")
            print(f"🎙️  Speakers: {results['speakers_count']}")
            print(f"📝 Segments: {results['segments_count']}")
            print(f"📁 SRT: {results['subtitle_files']['srt']}")
        else:
            print(f"❌ FAILED: {results['error']}")
            
    except Exception as e:
        print(f"❌ ERROR: {e}")
    
    print("-" * 50)

# Example usage:
# quick_test("https://youtu.be/zYJKq17GpEc")
# quick_test("path/to/your/video.mp4")

print("Quick test function ready! Use quick_test('your_url_or_file') to test.")
